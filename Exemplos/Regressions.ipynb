# %%
import freeman as fm
import pandas as pd

regress = pd.read_csv('regressao.csv')
fm.linregress(regress,['Popularidade','Clustering Coefficient'],'Cache')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Cache   R-squared (uncentered):                   0.597
# Model:                            OLS   Adj. R-squared (uncentered):              0.591
# Method:                 Least Squares   F-statistic:                              94.97
# ...

# %%
fm.linregress(regress,['Popularidade','Densidade'],'Cache')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Cache   R-squared (uncentered):                   0.595
# Model:                            OLS   Adj. R-squared (uncentered):              0.588
# Method:                 Least Squares   F-statistic:                              93.85
# Date:                Mon, 02 Dec 2019   Prob (F-statistic):                    8.08e-26
# Time:                        20:17:50   Log-Likelihood:                         -1685.7
# No. Observations:                 130   AIC:                                      3375.
# Df Residuals:                     128   BIC:                                      3381.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
fm.linregress(regress,['Popularidade','Indegree'],'Cache')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Cache   R-squared (uncentered):                   0.599
# Model:                            OLS   Adj. R-squared (uncentered):              0.593
# Method:                 Least Squares   F-statistic:                              95.59
# Date:                Mon, 02 Dec 2019   Prob (F-statistic):                    4.01e-26
# Time:                        20:18:03   Log-Likelihood:                         -1685.0
# No. Observations:                 130   AIC:                                      3374.
# Df Residuals:                     128   BIC:                                      3380.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...
